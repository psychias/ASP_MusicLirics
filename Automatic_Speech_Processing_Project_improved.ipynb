# %% [markdown]
# # Automatic Speech Processing Final Year Project
#
# ---

# %%
pip install openai-whisper
# Out:
# Collecting openai-whisper
#   Downloading openai-whisper-20231117.tar.gz (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 6.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.3.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Collecting tiktoken (from openai-whisper)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.14.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.12.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->openai-whisper)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->openai-whisper)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->openai-whisper)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->openai-whisper)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->openai-whisper)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->openai-whisper)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->openai-whisper)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->openai-whisper)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801358 sha256=8a9510de0efbc388f8ed1689a10a8c580f076c266e2fd275ae37bd61e7aec311
#   Stored in directory: /root/.cache/pip/wheels/d0/85/e1/9361b4cbea7dd4b7f6702fa4c3afc94877952eeb2b62f45f56
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 openai-whisper-20231117 tiktoken-0.7.0

# %%
pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.9.3

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
pip install textdistance
# Out:
# Collecting textdistance
#   Downloading textdistance-4.6.2-py3-none-any.whl (31 kB)
# Installing collected packages: textdistance
# Successfully installed textdistance-4.6.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries

# %%
import os
import whisper
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from pydub import AudioSegment
import textdistance
import jiwer
from collections import Counter

# %% [markdown]
# ## Load Songs

# %%
songs_dir = "/content/drive/MyDrive/FinalProject/data/songs/"
transcripts_dir = "/content/drive/MyDrive/FinalProject/data/transcripts/"
output_dir = "/content/drive/MyDrive/FinalProject/data/output_transcripts/"
os.makedirs(output_dir, exist_ok=True)
#songs.sort()
#transcripts.sort()

# %% [markdown]
# ## Load the Whisper Model:

# %%
model = whisper.load_model("medium")
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 95.0MiB/s]

# %% [markdown]
# ## Define Functions

# %%
def convert_mp3_to_wav(mp3_file, wav_file):
    audio = AudioSegment.from_mp3(mp3_file)
    audio.export(wav_file, format="wav")

def transcribe_audio(wav_file):
    result = model.transcribe(wav_file)
    return result['text']

# %% [markdown]
# ## Transcription and Comparison:

# %%
transformation = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.RemovePunctuation(),
    jiwer.Strip()
])

# %%
results = []
accuracies = []
mismatched_words = []

for song_file in sorted(os.listdir(songs_dir)):
    if song_file.endswith(".mp3"):
        song_path = os.path.join(songs_dir, song_file)
        transcript_path = os.path.join(transcripts_dir, song_file.replace(".mp3", ".txt"))

        wav_path = song_path.replace(".mp3", ".wav")

        convert_mp3_to_wav(song_path, wav_path)
        transcription = transcribe_audio(wav_path)

        with open(transcript_path, 'r') as file:
            human_transcript = file.read().strip()

        ground_truth = transformation(human_transcript)
        hypothesis = transformation(transcription)

        measures = jiwer.compute_measures(ground_truth, hypothesis)
        accuracy = max((1 - measures['wer']) * 100, 0)
        results.append(accuracy)
        accuracies.append((song_file, accuracy))

        ground_words = ground_truth.split()
        hypo_words = hypothesis.split()
        mismatches = [(truth, hypo) for truth, hypo in zip(ground_words, hypo_words) if truth != hypo]
        mismatched_words.extend(mismatches)

# %% [markdown]
# ## Comparison Results

# %%
# Overall Accuracy
overall_accuracy = sum(results) / len(results)
print(f"Overall Accuracy: {overall_accuracy:.2f}%")
# Out:
# Overall Accuracy: 51.30%

# %%
# Print the accuracies for each song
for song_name, accuracy in accuracies:
    print(f"Accuracy for {song_name}: {accuracy:.2f}%")
# Out:
# Accuracy for 01_Roddy_Ricch_The_Box.mp3: 59.01%
# Accuracy for 02_Future_Life_Is_Good.mp3: 52.37%
# Accuracy for 03_Post_Malone_Circles.mp3: 54.30%
# Accuracy for 04_Maroon_5_Memories.mp3: 60.05%
# Accuracy for 05_Lewis_Capaldi_Someone_You_Loved.mp3: 38.10%
# Accuracy for 06_Tones_and_I_Dance_Monkey.mp3: 46.45%
# Accuracy for 07_Arizona_Zervas_ROXANNE.mp3: 46.32%
# Accuracy for 08_Lizzo_Truth_Hurts.mp3: 54.73%
# Accuracy for 09_Dua_Lipa_Don_t_Start_Now.mp3: 53.15%
# Accuracy for 10_Billie_Eilish_everything_i_wanted.mp3: 55.38%
# Accuracy for 11_Selena_Gomez_Lose_You_To_Love_Me.mp3: 51.71%
# Accuracy for 12_Ed_Sheeran_I_Don_t_Care.mp3: 62.45%
# Accuracy for 13_DaBaby_BOP.mp3: 64.95%
# Accuracy for 14_Justin_Bieber_Yummy.mp3: 48.03%
# Accuracy for 15_The_Weeknd_Blinding_Lights.mp3: 61.88%
# Accuracy for 16_Lizzo_Good_as_Hell.mp3: 46.28%
# Accuracy for 17_The_Weeknd_Heartless.mp3: 54.84%
# Accuracy for 18_Maren_Morris_The_Bones.mp3: 59.31%
# Accuracy for 19_Blackbear_hot_girl_bummer.mp3: 57.04%
# Accuracy for 20_Eminem_Godzilla_(feat._Juice_WRLD).mp3: 52.60%
# Accuracy for 21_Roddy_Ricch_High_Fashion_(feat._Mustard).mp3: 65.60%
# Accuracy for 22_Chris_Brown_No_Guidance.mp3: 53.51%
# Accuracy for 23_Harry_Styles_Adore_You.mp3: 34.83%
# Accuracy for 24_Lil_Baby_Woah.mp3: 0.00%
# Accuracy for 25_Billie_Eilish_bad_guy.mp3: 46.15%
# Accuracy for 26_Travis_Scott_HIGHEST_IN_THE_ROOM.mp3: 36.42%
# Accuracy for 27_Harry_Styles_Falling.mp3: 68.72%
# Accuracy for 28_Shawn_Mendes_Señorita.mp3: 49.00%
# Accuracy for 29_Jonas_Brothers_What_a_Man_Gotta_Do.mp3: 47.77%
# Accuracy for 30_Halsey_You_should_be_sad.mp3: 57.99%

# %% [markdown]
# ## Result Visulization

# %%
# Visualization of Individual Song Accuracies
plt.figure(figsize=(12, 6))
plt.bar(range(len(results)), results, color='green')
plt.xlabel('Song Number')
plt.ylabel('Transcription Accuracy (%)')
plt.title('Whisper Transcription Accuracy for Songs')
plt.xticks(range(len(results)), [a[0].replace('.mp3', '') for a in accuracies], rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Print mismatched words
print("Mismatched Words:")
mismatch_counter = Counter(mismatched_words)
for (truth, hypo), count in mismatch_counter.items():
    print(f"Expected: '{truth}', Transcribed: '{hypo}' - Occurred {count} times")
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected: 'aint', Transcribed: 'whip' - Occurred 1 times
# Expected: 'free', Transcribed: 'with' - Occurred 1 times
# Expected: 'she', Transcribed: 'that' - Occurred 2 times
# Expected: 'be', Transcribed: 'blunt' - Occurred 1 times
# Expected: 'throwin', Transcribed: 'and' - Occurred 1 times
# Expected: 'ass', Transcribed: 'mom' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'watch' - Occurred 1 times
# Expected: 'good', Transcribed: 'swervin' - Occurred 1 times
# Expected: 'at', Transcribed: 'that' - Occurred 1 times
# Expected: 'it', Transcribed: 'whip' - Occurred 1 times
# Expected: 'turn', Transcribed: 'had' - Occurred 1 times
# Expected: 'around', Transcribed: 'a' - Occurred 1 times
# Expected: 'when', Transcribed: 'cop' - Occurred 1 times
# Expected: 'we', Transcribed: 'in' - Occurred 1 times
# Expected: 'fuck', Transcribed: 'it' - Occurred 1 times
# Expected: 'make', Transcribed: 'my' - Occurred 2 times
# Expected: 'her', Transcribed: 'bitch' - Occurred 1 times
# Expected: 'look', Transcribed: 'got' - Occurred 1 times
# Expected: 'at', Transcribed: 'good' - Occurred 1 times
# Expected: 'it', Transcribed: 'pussy' - Occurred 1 times
# Expected: 'uh', Transcribed: 'fly' - Occurred 1 times
# Expected: 'she', Transcribed: 'her' - Occurred 1 times
# Expected: 'like', Transcribed: 'across' - Occurred 1 times
# Expected: 'hah', Transcribed: 'the' - Occurred 1 times
# Expected: 'i', Transcribed: 'country' - Occurred 1 times
# Expected: 'needed', Transcribed: 'i' - Occurred 1 times
# Expected: 'some', Transcribed: 'finished' - Occurred 1 times
# Expected: 'shit', Transcribed: 'the' - Occurred 1 times
# Expected: 'with', Transcribed: 'show' - Occurred 1 times
# Expected: 'some', Transcribed: 'and' - Occurred 1 times
# Expected: 'bop', Transcribed: 'i' - Occurred 1 times
# Expected: 'in', Transcribed: 'hop' - Occurred 1 times
# Expected: 'it', Transcribed: 'in' - Occurred 2 times
# Expected: 'lets', Transcribed: 'it' - Occurred 1 times
# Expected: 'go', Transcribed: 'i' - Occurred 4 times
# Expected: 'flew', Transcribed: 'me' - Occurred 1 times
# Expected: 'past', Transcribed: 'a' - Occurred 1 times
# Expected: 'the', Transcribed: 'milli' - Occurred 1 times
# Expected: 'whip', Transcribed: 'i' - Occurred 1 times
# Expected: 'with', Transcribed: 'did' - Occurred 1 times
# Expected: 'that', Transcribed: 'it' - Occurred 1 times
# Expected: 'blunt', Transcribed: 'legitly' - Occurred 1 times
# Expected: 'my', Transcribed: 'still' - Occurred 1 times
# Expected: 'mouth', Transcribed: 'with' - Occurred 1 times
# Expected: 'watch', Transcribed: 'the' - Occurred 1 times
# Expected: 'the', Transcribed: 'shits' - Occurred 1 times
# Expected: 'swervin', Transcribed: 'im' - Occurred 1 times
# Expected: 'whip', Transcribed: 'hot' - Occurred 1 times
# Expected: 'had', Transcribed: 'nigga' - Occurred 1 times
# Expected: 'a', Transcribed: 'im' - Occurred 3 times
# Expected: 'cop', Transcribed: 'on' - Occurred 1 times
# Expected: 'in', Transcribed: 'another' - Occurred 1 times
# Expected: 'it', Transcribed: 'docks' - Occurred 1 times
# Expected: 'woo', Transcribed: 'than' - Occurred 1 times
# Expected: 'okay', Transcribed: 'a' - Occurred 1 times
# Expected: 'my', Transcribed: 'motherfucker' - Occurred 1 times
# Expected: 'bitch', Transcribed: 'ay' - Occurred 1 times
# Expected: 'got', Transcribed: 'when' - Occurred 1 times
# Expected: 'good', Transcribed: 'you' - Occurred 1 times
# Expected: 'pussy', Transcribed: 'gon' - Occurred 1 times
# Expected: 'fly', Transcribed: 'switch' - Occurred 1 times
# Expected: 'her', Transcribed: 'the' - Occurred 2 times
# Expected: 'cross', Transcribed: 'flow' - Occurred 1 times
# Expected: 'country', Transcribed: 'thought' - Occurred 1 times
# Expected: 'finish', Transcribed: 'never' - Occurred 1 times
# Expected: 'the', Transcribed: 'asked' - Occurred 1 times
# Expected: 'show', Transcribed: 'niggas' - Occurred 1 times
# Expected: 'and', Transcribed: 'aint' - Occurred 1 times
# Expected: 'i', Transcribed: 'fuckin' - Occurred 1 times
# Expected: 'hop', Transcribed: 'with' - Occurred 1 times
# Expected: 'in', Transcribed: 'me' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'aint' - Occurred 3 times
# Expected: 'i', Transcribed: 'bout' - Occurred 1 times
# Expected: 'got', Transcribed: 'with' - Occurred 1 times
# Expected: 'a', Transcribed: 'fuck' - Occurred 1 times
# Expected: 'milli', Transcribed: 'they' - Occurred 1 times
# Expected: 'did', Transcribed: 'rappin' - Occurred 1 times
# Expected: 'it', Transcribed: 'bout' - Occurred 1 times
# Expected: 'legitly', Transcribed: 'with' - Occurred 1 times
# Expected: 'im', Transcribed: 'they' - Occurred 4 times
# Expected: 'still', Transcribed: 'look' - Occurred 1 times
# Expected: 'with', Transcribed: 'scary' - Occurred 1 times
# Expected: 'the', Transcribed: 'ass' - Occurred 1 times
# Expected: 'shits', Transcribed: 'but' - Occurred 1 times
# Expected: 'im', Transcribed: 'to' - Occurred 3 times
# Expected: 'a', Transcribed: 'each' - Occurred 1 times
# Expected: 'hot', Transcribed: 'his' - Occurred 1 times
# Expected: 'nigga', Transcribed: 'own' - Occurred 1 times
# Expected: 'lets', Transcribed: 'if' - Occurred 1 times
# Expected: 'go', Transcribed: 'you' - Occurred 3 times
# Expected: 'unorthodox', Transcribed: 'it' - Occurred 1 times
# Expected: 'than', Transcribed: 'i' - Occurred 1 times
# Expected: 'a', Transcribed: 'love' - Occurred 1 times
# Expected: 'motherfucker', Transcribed: 'it' - Occurred 1 times
# Expected: 'ayy', Transcribed: 'no' - Occurred 1 times
# Expected: 'when', Transcribed: 'big' - Occurred 1 times
# Expected: 'gon', Transcribed: 'boy' - Occurred 1 times
# Expected: 'switch', Transcribed: 'say' - Occurred 1 times
# Expected: 'the', Transcribed: 'he' - Occurred 1 times
# Expected: 'flow', Transcribed: 'get' - Occurred 1 times
# Expected: 'i', Transcribed: 'money' - Occurred 1 times
# Expected: 'thought', Transcribed: 'oh' - Occurred 1 times
# Expected: 'youd', Transcribed: 'really' - Occurred 1 times
# Expected: 'never', Transcribed: 'how' - Occurred 1 times
# Expected: 'ask', Transcribed: 'much' - Occurred 1 times
# Expected: 'aint', Transcribed: 'just' - Occurred 1 times
# Expected: 'fuckin', Transcribed: 'cut' - Occurred 1 times
# Expected: 'me', Transcribed: 'a' - Occurred 6 times
# Expected: 'and', Transcribed: 'check' - Occurred 2 times
# Expected: 'aint', Transcribed: 'for' - Occurred 1 times
# Expected: 'bout', Transcribed: 'a' - Occurred 1 times
# Expected: 'what', Transcribed: 'milli' - Occurred 1 times
# Expected: 'fuck', Transcribed: 'going' - Occurred 1 times
# Expected: 'they', Transcribed: 'back' - Occurred 2 times
# Expected: 'be', Transcribed: 'to' - Occurred 2 times
# Expected: 'rappin', Transcribed: 'cali' - Occurred 1 times
# Expected: 'bout', Transcribed: 'like' - Occurred 1 times
# Expected: 'with', Transcribed: 'big' - Occurred 1 times
# Expected: 'they', Transcribed: 'bout' - Occurred 1 times
# Expected: 'lil', Transcribed: 'to' - Occurred 1 times
# Expected: 'scary', Transcribed: 'go' - Occurred 1 times
# Expected: 'ass', Transcribed: 'get' - Occurred 1 times
# Expected: 'hah', Transcribed: 'a' - Occurred 1 times
# Expected: 'but', Transcribed: 'pound' - Occurred 1 times
# Expected: 'to', Transcribed: 'just' - Occurred 2 times
# Expected: 'each', Transcribed: 'to' - Occurred 1 times
# Expected: 'his', Transcribed: 'smoke' - Occurred 1 times
# Expected: 'own', Transcribed: 'they' - Occurred 1 times
# Expected: 'nigga', Transcribed: 'told' - Occurred 1 times
# Expected: 'huh', Transcribed: 'me' - Occurred 1 times
# Expected: 'if', Transcribed: 'to' - Occurred 1 times
# Expected: 'you', Transcribed: 'come' - Occurred 1 times
# Expected: 'like', Transcribed: 'work' - Occurred 1 times
# Expected: 'it', Transcribed: 'on' - Occurred 1 times
# Expected: 'love', Transcribed: 'album' - Occurred 1 times
# Expected: 'it', Transcribed: 'im' - Occurred 2 times
# Expected: 'no', Transcribed: 'tryna' - Occurred 1 times
# Expected: 'biggie', Transcribed: 'go' - Occurred 1 times
# Expected: 'no', Transcribed: 'find' - Occurred 1 times
# Expected: 'big', Transcribed: 'out' - Occurred 1 times
# Expected: 'boy', Transcribed: 'price' - Occurred 1 times
# Expected: 'say', Transcribed: 'on' - Occurred 3 times
# Expected: 'he', Transcribed: 'the' - Occurred 1 times
# Expected: 'get', Transcribed: 'boat' - Occurred 1 times
# Expected: 'money', Transcribed: 'my' - Occurred 1 times
# Expected: 'oh', Transcribed: 'lil' - Occurred 1 times
# Expected: 'really', Transcribed: 'bitch' - Occurred 1 times
# Expected: 'how', Transcribed: 'act' - Occurred 1 times
# Expected: 'much', Transcribed: 'like' - Occurred 1 times
# Expected: 'they', Transcribed: 'megan' - Occurred 1 times
# Expected: 'just', Transcribed: 'thee' - Occurred 1 times
# Expected: 'cut', Transcribed: 'stallion' - Occurred 1 times
# Expected: 'you', Transcribed: 'she' - Occurred 2 times
# Expected: 'a', Transcribed: 'get' - Occurred 1 times
# Expected: 'check', Transcribed: 'on' - Occurred 1 times
# Expected: 'for', Transcribed: 'with' - Occurred 1 times
# Expected: 'a', Transcribed: 'nasty' - Occurred 1 times
# Expected: 'milli', Transcribed: 'she' - Occurred 1 times
# Expected: 'im', Transcribed: 'drivin' - Occurred 1 times
# Expected: 'goin', Transcribed: 'the' - Occurred 1 times
# Expected: 'back', Transcribed: 'boat' - Occurred 1 times
# Expected: 'to', Transcribed: 'all' - Occurred 2 times
# Expected: 'cali', Transcribed: 'this' - Occurred 1 times
# Expected: 'like', Transcribed: 'shit' - Occurred 1 times
# Expected: 'biggie', Transcribed: 'that' - Occurred 1 times
# Expected: 'go', Transcribed: 'they' - Occurred 1 times
# Expected: 'back', Transcribed: 'make' - Occurred 1 times
# Expected: 'bout', Transcribed: 'in' - Occurred 1 times
# Expected: 'to', Transcribed: 'bbomb' - Occurred 1 times
# Expected: 'go', Transcribed: 'tell' - Occurred 1 times
# Expected: 'get', Transcribed: 'me' - Occurred 1 times
# Expected: 'a', Transcribed: 'somethin' - Occurred 1 times
# Expected: 'pound', Transcribed: 'to' - Occurred 1 times
# Expected: 'just', Transcribed: 'bop' - Occurred 1 times
# Expected: 'to', Transcribed: 'while' - Occurred 1 times
# Expected: 'smoke', Transcribed: 'i' - Occurred 1 times
# Expected: 'i', Transcribed: 'ride' - Occurred 1 times
# Expected: 'smoke', Transcribed: 'with' - Occurred 1 times
# Expected: 'they', Transcribed: 'the' - Occurred 3 times
# Expected: 'told', Transcribed: 'pope' - Occurred 1 times
# Expected: 'come', Transcribed: 'go' - Occurred 2 times
# Expected: 'work', Transcribed: 'ha' - Occurred 1 times
# Expected: 'my', Transcribed: 'needed' - Occurred 1 times
# Expected: 'album', Transcribed: 'some' - Occurred 1 times
# Expected: 'im', Transcribed: 'shit' - Occurred 1 times
# Expected: 'tryna', Transcribed: 'with' - Occurred 1 times
# Expected: 'go', Transcribed: 'some' - Occurred 1 times
# Expected: 'find', Transcribed: 'bob' - Occurred 1 times
# Expected: 'out', Transcribed: 'ellington' - Occurred 1 times
# Expected: 'price', Transcribed: 'flip' - Occurred 1 times
# Expected: 'on', Transcribed: 'ass' - Occurred 2 times
# Expected: 'boat', Transcribed: 'whip' - Occurred 1 times
# Expected: 'okay', Transcribed: 'with' - Occurred 1 times
# Expected: 'my', Transcribed: 'that' - Occurred 4 times
# Expected: 'lil', Transcribed: 'blunt' - Occurred 1 times
# Expected: 'bitch', Transcribed: 'and' - Occurred 1 times
# Expected: 'act', Transcribed: 'my' - Occurred 1 times
# Expected: 'like', Transcribed: 'mom' - Occurred 1 times
# Expected: 'megan', Transcribed: 'watch' - Occurred 1 times
# Expected: 'thee', Transcribed: 'the' - Occurred 1 times
# Expected: 'stallion', Transcribed: 'swervin' - Occurred 1 times
# Expected: 'ghetto', Transcribed: 'whip' - Occurred 1 times
# Expected: 'nasty', Transcribed: 'a' - Occurred 1 times
# Expected: 'shes', Transcribed: 'cop' - Occurred 1 times
# Expected: 'drivin', Transcribed: 'in' - Occurred 1 times
# Expected: 'boat', Transcribed: 'my' - Occurred 1 times
# Expected: 'drive', Transcribed: 'bitch' - Occurred 1 times
# Expected: 'boat', Transcribed: 'good' - Occurred 1 times
# Expected: 'all', Transcribed: 'pussy' - Occurred 1 times
# Expected: 'this', Transcribed: 'fly' - Occurred 1 times
# Expected: 'shit', Transcribed: 'her' - Occurred 1 times
# Expected: 'that', Transcribed: 'across' - Occurred 1 times
# Expected: 'makin', Transcribed: 'country' - Occurred 1 times
# Expected: 'be', Transcribed: 'i' - Occurred 1 times
# Expected: 'boring', Transcribed: 'finished' - Occurred 1 times
# Expected: 'play', Transcribed: 'the' - Occurred 1 times
# Expected: 'me', Transcribed: 'show' - Occurred 1 times
# Expected: 'something', Transcribed: 'and' - Occurred 1 times
# Expected: 'bop', Transcribed: 'hop' - Occurred 1 times
# Expected: 'while', Transcribed: 'in' - Occurred 1 times
# Expected: 'ride', Transcribed: 'i' - Occurred 1 times
# Expected: 'with', Transcribed: 'got' - Occurred 2 times
# Expected: 'pole', Transcribed: 'a' - Occurred 1 times
# Expected: 'here', Transcribed: 'milli' - Occurred 1 times
# Expected: 'go', Transcribed: 'did' - Occurred 1 times
# Expected: 'uh', Transcribed: 'it' - Occurred 1 times
# Expected: 'oh', Transcribed: 'legit' - Occurred 1 times
# Expected: 'hah', Transcribed: 'im' - Occurred 1 times
# Expected: 'okay', Transcribed: 'still' - Occurred 1 times
# Expected: 'needed', Transcribed: 'the' - Occurred 1 times
# Expected: 'some', Transcribed: 'shit' - Occurred 2 times
# Expected: 'shit', Transcribed: 'im' - Occurred 1 times
# Expected: 'some', Transcribed: 'hot' - Occurred 1 times
# Expected: 'bop', Transcribed: 'nigga' - Occurred 1 times
# Expected: 'in', Transcribed: 'like' - Occurred 2 times
# Expected: 'it', Transcribed: 'this' - Occurred 1 times
# Expected: 'lets', Transcribed: 'shit' - Occurred 1 times
# Expected: 'go', Transcribed: 'feel' - Occurred 1 times
# Expected: 'flew', Transcribed: 'you' - Occurred 1 times
# Expected: 'past', Transcribed: 'know' - Occurred 1 times
# Expected: 'whip', Transcribed: 'sophisticated' - Occurred 1 times
# Expected: 'with', Transcribed: 'ratchet' - Occurred 1 times
# Expected: 'that', Transcribed: 'hoe' - Occurred 1 times
# Expected: 'blunt', Transcribed: 'you' - Occurred 1 times
# Expected: 'in', Transcribed: 'know' - Occurred 2 times
# Expected: 'mouth', Transcribed: 'ones' - Occurred 1 times
# Expected: 'watch', Transcribed: 'that' - Occurred 1 times
# Expected: 'the', Transcribed: 'go' - Occurred 3 times
# Expected: 'swervin', Transcribed: 'to' - Occurred 1 times
# Expected: 'that', Transcribed: 'work' - Occurred 1 times
# Expected: 'whip', Transcribed: 'by' - Occurred 1 times
# Expected: 'had', Transcribed: 'day' - Occurred 1 times
# Expected: 'a', Transcribed: 'then' - Occurred 1 times
# Expected: 'cop', Transcribed: 'you' - Occurred 1 times
# Expected: 'it', Transcribed: 'dancing' - Occurred 1 times
# Expected: 'bitch', Transcribed: 'mirror' - Occurred 1 times
# Expected: 'got', Transcribed: 'by' - Occurred 1 times
# Expected: 'good', Transcribed: 'night' - Occurred 1 times
# Expected: 'pussy', Transcribed: 'ha' - Occurred 1 times
# Expected: 'fly', Transcribed: 'i' - Occurred 1 times
# Expected: 'her', Transcribed: 'needed' - Occurred 1 times
# Expected: 'cross', Transcribed: 'some' - Occurred 1 times
# Expected: 'country', Transcribed: 'with' - Occurred 1 times
# Expected: 'i', Transcribed: 'some' - Occurred 4 times
# Expected: 'finish', Transcribed: 'bob' - Occurred 1 times
# Expected: 'the', Transcribed: 'ellington' - Occurred 1 times
# Expected: 'show', Transcribed: 'i' - Occurred 2 times
# Expected: 'and', Transcribed: 'flip' - Occurred 1 times
# Expected: 'i', Transcribed: 'ass' - Occurred 2 times
# Expected: 'hop', Transcribed: 'and' - Occurred 1 times
# Expected: 'in', Transcribed: 'whip' - Occurred 1 times
# Expected: 'it', Transcribed: 'with' - Occurred 1 times
# Expected: 'got', Transcribed: 'blunt' - Occurred 1 times
# Expected: 'a', Transcribed: 'my' - Occurred 5 times
# Expected: 'milli', Transcribed: 'mom' - Occurred 1 times
# Expected: 'i', Transcribed: 'watch' - Occurred 1 times
# Expected: 'did', Transcribed: 'the' - Occurred 1 times
# Expected: 'it', Transcribed: 'swervin' - Occurred 1 times
# Expected: 'legitly', Transcribed: 'that' - Occurred 1 times
# Expected: 'im', Transcribed: 'whip' - Occurred 1 times
# Expected: 'still', Transcribed: 'had' - Occurred 1 times
# Expected: 'the', Transcribed: 'cop' - Occurred 1 times
# Expected: 'shits', Transcribed: 'in' - Occurred 1 times
# Expected: 'im', Transcribed: 'it' - Occurred 1 times
# Expected: 'hot', Transcribed: 'bitch' - Occurred 1 times
# Expected: 'nigga', Transcribed: 'got' - Occurred 1 times
# Expected: 'im', Transcribed: 'good' - Occurred 2 times
# Expected: 'hot', Transcribed: 'pussy' - Occurred 1 times
# Expected: 'like', Transcribed: 'fly' - Occurred 1 times
# Expected: 'this', Transcribed: 'her' - Occurred 1 times
# Expected: 'shit', Transcribed: 'across' - Occurred 1 times
# Expected: 'feel', Transcribed: 'the' - Occurred 1 times
# Expected: 'like', Transcribed: 'country' - Occurred 1 times
# Expected: 'know', Transcribed: 'finished' - Occurred 1 times
# Expected: 'sophisticated', Transcribed: 'show' - Occurred 1 times
# Expected: 'ratchet', Transcribed: 'and' - Occurred 1 times
# Expected: 'hoes', Transcribed: 'i' - Occurred 1 times
# Expected: 'you', Transcribed: 'hop' - Occurred 1 times
# Expected: 'know', Transcribed: 'in' - Occurred 1 times
# Expected: 'ones', Transcribed: 'i' - Occurred 1 times
# Expected: 'go', Transcribed: 'me' - Occurred 1 times
# Expected: 'work', Transcribed: 'milli' - Occurred 1 times
# Expected: 'day', Transcribed: 'did' - Occurred 1 times
# Expected: 'then', Transcribed: 'it' - Occurred 1 times
# Expected: 'you', Transcribed: 'legit' - Occurred 1 times
# Expected: 'know', Transcribed: 'im' - Occurred 1 times
# Expected: 'dance', Transcribed: 'still' - Occurred 1 times
# Expected: 'in', Transcribed: 'with' - Occurred 2 times
# Expected: 'mirror', Transcribed: 'shit' - Occurred 1 times
# Expected: 'by', Transcribed: 'im' - Occurred 1 times
# Expected: 'night', Transcribed: 'a' - Occurred 1 times
# Expected: 'hah', Transcribed: 'hot' - Occurred 1 times
# Expected: 'i', Transcribed: 'nigga' - Occurred 1 times
# Expected: 'needed', Transcribed: 'oh' - Occurred 1 times
# Expected: 'some', Transcribed: 'you' - Occurred 1 times
# Expected: 'shit', Transcribed: 'askin' - Occurred 1 times
# Expected: 'with', Transcribed: 'for' - Occurred 1 times
# Expected: 'some', Transcribed: 'pictures' - Occurred 1 times
# Expected: 'bop', Transcribed: 'with' - Occurred 1 times
# Expected: 'in', Transcribed: 'niggas' - Occurred 2 times
# Expected: 'it', Transcribed: 'get' - Occurred 1 times
# Expected: 'okay', Transcribed: 'the' - Occurred 2 times
# Expected: 'lets', Transcribed: 'fuck' - Occurred 1 times
# Expected: 'go', Transcribed: 'out' - Occurred 1 times
# Expected: 'flew', Transcribed: 'spot' - Occurred 1 times
# Expected: 'past', Transcribed: 'nigga' - Occurred 1 times
# Expected: 'the', Transcribed: 'tryna' - Occurred 1 times
# Expected: 'whip', Transcribed: 'figure' - Occurred 1 times
# Expected: 'with', Transcribed: 'which' - Occurred 1 times
# Expected: 'that', Transcribed: 'deal' - Occurred 1 times
# Expected: 'blunt', Transcribed: 'ima' - Occurred 1 times
# Expected: 'in', Transcribed: 'take' - Occurred 1 times
# Expected: 'mouth', Transcribed: 'woke' - Occurred 1 times
# Expected: 'watch', Transcribed: 'up' - Occurred 1 times
# Expected: 'the', Transcribed: 'couple' - Occurred 1 times
# Expected: 'swervin', Transcribed: 'mil' - Occurred 1 times
# Expected: 'that', Transcribed: 'ima' - Occurred 1 times
# Expected: 'whip', Transcribed: 'kill' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'yummy' - Occurred 2 times
# Expected: 'that', Transcribed: 'yummy' - Occurred 2 times
# Expected: 'yummyyummy', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'yummy' - Occurred 4 times
# Expected: 'you', Transcribed: 'say' - Occurred 3 times
# Expected: 'got', Transcribed: 'the' - Occurred 4 times
# Expected: 'that', Transcribed: 'word' - Occurred 2 times
# Expected: 'yummyyum', Transcribed: 'on' - Occurred 2 times
# Expected: 'yummyyum', Transcribed: 'way' - Occurred 2 times
# Expected: 'that', Transcribed: 'yeah' - Occurred 7 times
# Expected: 'yummyyummy', Transcribed: 'babe' - Occurred 3 times
# Expected: 'say', Transcribed: 'yeah' - Occurred 2 times
# Expected: 'the', Transcribed: 'babe' - Occurred 3 times
# Expected: 'word', Transcribed: 'yeah' - Occurred 2 times
# Expected: 'on', Transcribed: 'babe' - Occurred 3 times
# Expected: 'my', Transcribed: 'any' - Occurred 1 times
# Expected: 'way', Transcribed: 'day' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'any' - Occurred 1 times
# Expected: 'babe', Transcribed: 'day' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'say' - Occurred 2 times
# Expected: 'babe', Transcribed: 'the' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'word' - Occurred 2 times
# Expected: 'babe', Transcribed: 'on' - Occurred 1 times
# Expected: 'any', Transcribed: 'my' - Occurred 1 times
# Expected: 'night', Transcribed: 'way' - Occurred 1 times
# Expected: 'any', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'day', Transcribed: 'babe' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'morning' - Occurred 1 times
# Expected: 'babe', Transcribed: 'all' - Occurred 1 times
# Expected: 'babe', Transcribed: 'say' - Occurred 1 times
# Expected: 'babe', Transcribed: 'word' - Occurred 2 times
# Expected: 'mornin', Transcribed: 'way' - Occurred 1 times
# Expected: 'or', Transcribed: 'bonafide' - Occurred 1 times
# Expected: 'the', Transcribed: 'stallion' - Occurred 1 times
# Expected: 'late', Transcribed: 'aint' - Occurred 1 times
# Expected: 'say', Transcribed: 'in' - Occurred 2 times
# Expected: 'the', Transcribed: 'no' - Occurred 4 times
# Expected: 'word', Transcribed: 'stable' - Occurred 1 times
# Expected: 'on', Transcribed: 'no' - Occurred 1 times
# Expected: 'way', Transcribed: 'stay' - Occurred 1 times
# Expected: 'bona', Transcribed: 'on' - Occurred 1 times
# Expected: 'fide', Transcribed: 'the' - Occurred 1 times
# Expected: 'stallion', Transcribed: 'run' - Occurred 1 times
# Expected: 'no', Transcribed: 'the' - Occurred 3 times
# Expected: 'stable', Transcribed: 'side' - Occurred 1 times
# Expected: 'no', Transcribed: 'youre' - Occurred 1 times
# Expected: 'you', Transcribed: 'number' - Occurred 1 times
# Expected: 'stay', Transcribed: 'one' - Occurred 1 times
# Expected: 'on', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'the', Transcribed: 'every' - Occurred 2 times
# Expected: 'run', Transcribed: 'time' - Occurred 1 times
# Expected: 'on', Transcribed: 'come' - Occurred 1 times
# Expected: 'the', Transcribed: 'around' - Occurred 1 times
# Expected: 'side', Transcribed: 'you' - Occurred 1 times
# Expected: 'youre', Transcribed: 'get' - Occurred 1 times
# Expected: 'number', Transcribed: 'it' - Occurred 1 times
# Expected: 'one', Transcribed: 'done' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'fiftyfifty' - Occurred 1 times
# Expected: 'every', Transcribed: 'love' - Occurred 1 times
# Expected: 'time', Transcribed: 'the' - Occurred 2 times
# Expected: 'i', Transcribed: 'way' - Occurred 1 times
# Expected: 'come', Transcribed: 'you' - Occurred 2 times
# Expected: 'around', Transcribed: 'splint' - Occurred 1 times
# Expected: 'get', Transcribed: 'on' - Occurred 3 times
# Expected: 'done', Transcribed: 'racks' - Occurred 1 times
# Expected: 'fiftyfifty', Transcribed: 'tell' - Occurred 1 times
# Expected: 'the', Transcribed: 'spin' - Occurred 1 times
# Expected: 'way', Transcribed: 'it' - Occurred 1 times
# Expected: 'you', Transcribed: 'babe' - Occurred 5 times
# Expected: 'split', Transcribed: 'like' - Occurred 1 times
# Expected: 'hundred', Transcribed: 'magic' - Occurred 1 times
# Expected: 'racks', Transcribed: 'get' - Occurred 1 times
# Expected: 'help', Transcribed: 'lit' - Occurred 1 times
# Expected: 'me', Transcribed: 'babe' - Occurred 2 times
# Expected: 'spend', Transcribed: 'that' - Occurred 1 times
# Expected: 'it', Transcribed: 'jet' - Occurred 2 times
# Expected: 'babe', Transcribed: 'set' - Occurred 1 times
# Expected: 'light', Transcribed: 'watch' - Occurred 1 times
# Expected: 'match', Transcribed: 'sunset' - Occurred 1 times
# Expected: 'get', Transcribed: 'come' - Occurred 1 times
# Expected: 'litty', Transcribed: 'home' - Occurred 1 times
# Expected: 'babe', Transcribed: 'yeah' - Occurred 5 times
# Expected: 'jet', Transcribed: 'rolling' - Occurred 1 times
# Expected: 'set', Transcribed: 'eyes' - Occurred 1 times
# Expected: 'watch', Transcribed: 'back' - Occurred 1 times
# Expected: 'sunset', Transcribed: 'my' - Occurred 1 times
# Expected: 'kinda', Transcribed: 'head' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'make' - Occurred 1 times
# Expected: 'rollin', Transcribed: 'toes' - Occurred 1 times
# Expected: 'eyes', Transcribed: 'curl' - Occurred 1 times
# Expected: 'back', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'my', Transcribed: 'yeah' - Occurred 2 times
# Expected: 'head', Transcribed: 'you' - Occurred 1 times
# Expected: 'make', Transcribed: 'got' - Occurred 1 times
# Expected: 'toes', Transcribed: 'yummy' - Occurred 2 times
# Expected: 'curl', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'you', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'got', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'that', Transcribed: 'say' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'the' - Occurred 1 times
# Expected: 'yummyyummy', Transcribed: 'way' - Occurred 1 times
# Expected: 'that', Transcribed: 'babe' - Occurred 4 times
# Expected: 'yummyyum', Transcribed: 'yeah' - Occurred 2 times
# Expected: 'yummyyum', Transcribed: 'any' - Occurred 1 times
# Expected: 'that', Transcribed: 'day' - Occurred 1 times
# Expected: 'yummyyummy', Transcribed: 'any' - Occurred 1 times
# Expected: 'say', Transcribed: 'day' - Occurred 1 times
# Expected: 'word', Transcribed: 'the' - Occurred 1 times
# Expected: 'on', Transcribed: 'word' - Occurred 1 times
# Expected: 'way', Transcribed: 'my' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'way' - Occurred 2 times
# Expected: 'yeah', Transcribed: 'babe' - Occurred 3 times
# Expected: 'any', Transcribed: 'babe' - Occurred 1 times
# Expected: 'night', Transcribed: 'in' - Occurred 1 times
# Expected: 'any', Transcribed: 'the' - Occurred 1 times
# Expected: 'day', Transcribed: 'morning' - Occurred 1 times
# Expected: 'say', Transcribed: 'all' - Occurred 1 times
# Expected: 'the', Transcribed: 'late' - Occurred 1 times
# Expected: 'word', Transcribed: 'say' - Occurred 1 times
# Expected: 'my', Transcribed: 'word' - Occurred 1 times
# Expected: 'way', Transcribed: 'on' - Occurred 1 times
# Expected: 'babe', Transcribed: 'way' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'standing' - Occurred 1 times
# Expected: 'babe', Transcribed: 'up' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'keep' - Occurred 2 times
# Expected: 'babe', Transcribed: 'me' - Occurred 1 times
# Expected: 'mornin', Transcribed: 'rise' - Occurred 1 times
# Expected: 'or', Transcribed: 'lost' - Occurred 1 times
# Expected: 'the', Transcribed: 'control' - Occurred 1 times
# Expected: 'late', Transcribed: 'of' - Occurred 1 times
# Expected: 'say', Transcribed: 'myself' - Occurred 1 times
# Expected: 'word', Transcribed: 'compromised' - Occurred 1 times
# Expected: 'on', Transcribed: 'youre' - Occurred 1 times
# Expected: 'my', Transcribed: 'incriminating' - Occurred 1 times
# Expected: 'way', Transcribed: 'no' - Occurred 1 times
# Expected: 'standin', Transcribed: 'disguise' - Occurred 1 times
# Expected: 'up', Transcribed: 'and' - Occurred 2 times
# Expected: 'keep', Transcribed: 'you' - Occurred 1 times
# Expected: 'me', Transcribed: 'aint' - Occurred 1 times
# Expected: 'on', Transcribed: 'never' - Occurred 2 times
# Expected: 'the', Transcribed: 'runnin' - Occurred 1 times
# Expected: 'rise', Transcribed: 'low' - Occurred 1 times
# Expected: 'lost', Transcribed: 'on' - Occurred 1 times
# Expected: 'control', Transcribed: 'supplies' - Occurred 1 times
# Expected: 'of', Transcribed: 'fiftyfifty' - Occurred 1 times
# Expected: 'myself', Transcribed: 'love' - Occurred 1 times
# Expected: 'compromised', Transcribed: 'way' - Occurred 1 times
# Expected: 'youre', Transcribed: 'you' - Occurred 1 times
# Expected: 'incriminating', Transcribed: 'splint' - Occurred 1 times
# Expected: 'disguise', Transcribed: 'on' - Occurred 1 times
# Expected: 'you', Transcribed: 'racks' - Occurred 1 times
# Expected: 'aint', Transcribed: 'tell' - Occurred 1 times
# Expected: 'never', Transcribed: 'me' - Occurred 1 times
# Expected: 'runnin', Transcribed: 'spin' - Occurred 1 times
# Expected: 'low', Transcribed: 'it' - Occurred 1 times
# Expected: 'supplies', Transcribed: 'like' - Occurred 1 times
# Expected: 'fiftyfifty', Transcribed: 'a' - Occurred 1 times
# Expected: 'love', Transcribed: 'magic' - Occurred 1 times
# Expected: 'way', Transcribed: 'lit' - Occurred 1 times
# Expected: 'split', Transcribed: 'that' - Occurred 1 times
# Expected: 'hundred', Transcribed: 'set' - Occurred 1 times
# Expected: 'racks', Transcribed: 'watch' - Occurred 1 times
# Expected: 'help', Transcribed: 'the' - Occurred 1 times
# Expected: 'me', Transcribed: 'sunset' - Occurred 1 times
# Expected: 'spend', Transcribed: 'come' - Occurred 1 times
# Expected: 'it', Transcribed: 'home' - Occurred 1 times
# Expected: 'light', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'a', Transcribed: 'rolling' - Occurred 1 times
# Expected: 'match', Transcribed: 'eyes' - Occurred 1 times
# Expected: 'litty', Transcribed: 'in' - Occurred 1 times
# Expected: 'babe', Transcribed: 'my' - Occurred 3 times
# Expected: 'that', Transcribed: 'head' - Occurred 1 times
# Expected: 'jet', Transcribed: 'make' - Occurred 1 times
# Expected: 'set', Transcribed: 'my' - Occurred 1 times
# Expected: 'watch', Transcribed: 'toes' - Occurred 1 times
# Expected: 'the', Transcribed: 'curl' - Occurred 1 times
# Expected: 'sunset', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'kinda', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'rollin', Transcribed: 'got' - Occurred 1 times
# Expected: 'eyes', Transcribed: 'that' - Occurred 1 times
# Expected: 'back', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'in', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'my', Transcribed: 'yummy' - Occurred 3 times
# Expected: 'head', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'make', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'curl', Transcribed: 'say' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'on' - Occurred 5 times
# Expected: 'you', Transcribed: 'my' - Occurred 3 times
# Expected: 'got', Transcribed: 'way' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'babe' - Occurred 3 times
# Expected: 'you', Transcribed: 'any' - Occurred 1 times
# Expected: 'stay', Transcribed: 'day' - Occurred 1 times
# Expected: 'flexin', Transcribed: 'any' - Occurred 1 times
# Expected: 'on', Transcribed: 'day' - Occurred 1 times
# Expected: 'me', Transcribed: 'say' - Occurred 2 times
# Expected: 'you', Transcribed: 'word' - Occurred 1 times
# Expected: 'got', Transcribed: 'on' - Occurred 2 times
# Expected: 'word', Transcribed: 'morning' - Occurred 1 times
# Expected: 'on', Transcribed: 'all' - Occurred 1 times
# Expected: 'my', Transcribed: 'late' - Occurred 1 times
# Expected: 'way', Transcribed: 'say' - Occurred 1 times
# Expected: 'babe', Transcribed: 'i' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'ran' - Occurred 1 times
# Expected: 'babe', Transcribed: 'a' - Occurred 1 times
# Expected: 'any', Transcribed: 'lambo' - Occurred 1 times
# Expected: 'night', Transcribed: 'im' - Occurred 1 times
# Expected: 'any', Transcribed: 'on' - Occurred 1 times
# Expected: 'day', Transcribed: 'my' - Occurred 1 times
# Expected: 'say', Transcribed: 'way' - Occurred 1 times
# Expected: 'the', Transcribed: 'true' - Occurred 1 times
# Expected: 'word', Transcribed: 'house' - Occurred 1 times
# Expected: 'on', Transcribed: 'slippers' - Occurred 1 times
# Expected: 'way', Transcribed: 'with' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'a' - Occurred 2 times
# Expected: 'babe', Transcribed: 'smile' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'face' - Occurred 1 times
# Expected: 'babe', Transcribed: 'im' - Occurred 1 times
# Expected: 'babe', Transcribed: 'lady' - Occurred 1 times
# Expected: 'in', Transcribed: 'that' - Occurred 1 times
# Expected: 'mornin', Transcribed: 'are' - Occurred 1 times
# Expected: 'or', Transcribed: 'my' - Occurred 1 times
# Expected: 'the', Transcribed: 'lady' - Occurred 1 times
# Expected: 'late', Transcribed: 'you' - Occurred 1 times
# Expected: 'say', Transcribed: 'got' - Occurred 1 times
# Expected: 'word', Transcribed: 'yum' - Occurred 1 times
# Expected: 'on', Transcribed: 'yum' - Occurred 2 times
# Expected: 'my', Transcribed: 'yum' - Occurred 2 times
# Expected: 'way', Transcribed: 'yum' - Occurred 2 times
# Expected: 'hop', Transcribed: 'yum' - Occurred 1 times
# Expected: 'in', Transcribed: 'you' - Occurred 3 times
# Expected: 'lambo', Transcribed: 'that' - Occurred 1 times
# Expected: 'im', Transcribed: 'yum' - Occurred 1 times
# Expected: 'drew', Transcribed: 'whoa' - Occurred 1 times
# Expected: 'house', Transcribed: 'whoa' - Occurred 1 times
# Expected: 'slippers', Transcribed: 'yeah' - Occurred 1 times
# Expected: 'smile', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'on', Transcribed: 'yummy' - Occurred 1 times
# Expected: 'face', Transcribed: 'say' - Occurred 1 times
# Expected: 'elated', Transcribed: 'word' - Occurred 1 times
# Expected: 'are', Transcribed: 'way' - Occurred 1 times
# Expected: 'lady', Transcribed: 'babe' - Occurred 1 times
# Expected: 'you', Transcribed: 'yeah' - Occurred 2 times
# Expected: 'got', Transcribed: 'babe' - Occurred 1 times
# Expected: 'yum', Transcribed: 'babe' - Occurred 1 times
# Expected: 'yum', Transcribed: 'any' - Occurred 2 times
# Expected: 'yum', Transcribed: 'day' - Occurred 1 times
# Expected: 'you', Transcribed: 'day' - Occurred 1 times
# Expected: 'got', Transcribed: 'say' - Occurred 2 times
# Expected: 'yum', Transcribed: 'word' - Occurred 1 times
# Expected: 'yumyum', Transcribed: 'on' - Occurred 1 times
# Expected: 'woah', Transcribed: 'my' - Occurred 2 times
# Expected: 'woahooh', Transcribed: 'way' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'in' - Occurred 1 times
# Expected: 'yummyyummy', Transcribed: 'morning' - Occurred 1 times
# Expected: 'you', Transcribed: 'late' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'word' - Occurred 1 times
# Expected: 'yummyyum', Transcribed: 'my' - Occurred 1 times
# Expected: 'that', Transcribed: 'way' - Occurred 1 times
# Expected: 'yeah', Transcribed: 'ive' - Occurred 1 times
# Expected: 'ive', Transcribed: 'been' - Occurred 1 times
# Expected: 'been', Transcribed: 'trying' - Occurred 1 times
# Expected: 'tryna', Transcribed: 'to' - Occurred 3 times
# Expected: 'withdrawals', Transcribed: 'a' - Occurred 1 times
# Expected: 'you', Transcribed: 'drought' - Occurred 1 times
# Expected: 'dont', Transcribed: 'you' - Occurred 5 times
# Expected: 'even', Transcribed: 'dont' - Occurred 1 times
# Expected: 'have', Transcribed: 'even' - Occurred 1 times
# Expected: 'do', Transcribed: 'to' - Occurred 1 times
# Expected: 'too', Transcribed: 'do' - Occurred 1 times
# Expected: 'you', Transcribed: 'much' - Occurred 1 times
# Expected: 'turn', Transcribed: 'can' - Occurred 1 times
# Expected: 'me', Transcribed: 'turn' - Occurred 1 times
# Expected: 'on', Transcribed: 'me' - Occurred 2 times
# Expected: 'with', Transcribed: 'on' - Occurred 1 times
# Expected: 'a', Transcribed: 'just' - Occurred 2 times
# Expected: 'touch', Transcribed: 'a' - Occurred 1 times
# Expected: 'baby', Transcribed: 'touch' - Occurred 1 times
# Expected: 'look', Transcribed: 'i' - Occurred 1 times
# Expected: 'around', Transcribed: 'look' - Occurred 1 times
# Expected: 'and', Transcribed: 'around' - Occurred 1 times
# Expected: 'sin', Transcribed: 'stained' - Occurred 1 times
# Expected: 'citys', Transcribed: 'cities' - Occurred 1 times
# Expected: 'oh', Transcribed: 'no' - Occurred 2 times
# Expected: 'ones', Transcribed: 'around' - Occurred 1 times
# Expected: 'around', Transcribed: 'to' - Occurred 2 times
# Expected: 'to', Transcribed: 'judge' - Occurred 1 times
# Expected: 'judge', Transcribed: 'me' - Occurred 1 times
# Expected: 'oh', Transcribed: 'can' - Occurred 1 times
# Expected: 'cant', Transcribed: 'clearly' - Occurred 1 times
# Expected: 'see', Transcribed: 'when' - Occurred 2 times
# Expected: 'clearly', Transcribed: 'youre' - Occurred 1 times
# Expected: 'when', Transcribed: 'gone' - Occurred 1 times
# Expected: 'youre', Transcribed: 'i' - Occurred 1 times
# Expected: 'gone', Transcribed: 'said' - Occurred 1 times
# Expected: 'i', Transcribed: 'ooh' - Occurred 4 times
# Expected: 'said', Transcribed: 'im' - Occurred 2 times
# Expected: 'ooh', Transcribed: 'blinded' - Occurred 1 times
# Expected: 'im', Transcribed: 'by' - Occurred 2 times
# Expected: 'blinded', Transcribed: 'the' - Occurred 1 times
# Expected: 'by', Transcribed: 'lights' - Occurred 1 times
# Expected: 'lights', Transcribed: 'i' - Occurred 2 times
# Expected: 'no', Transcribed: 'cant' - Occurred 4 times
# Expected: 'i', Transcribed: 'sleep' - Occurred 1 times
# Expected: 'cant', Transcribed: 'until' - Occurred 1 times
# Expected: 'sleep', Transcribed: 'i' - Occurred 1 times
# Expected: 'until', Transcribed: 'feel' - Occurred 1 times
# Expected: 'feel', Transcribed: 'touch' - Occurred 1 times
# Expected: 'touch', Transcribed: 'said' - Occurred 1 times
# Expected: 'ooh', Transcribed: 'drowning' - Occurred 1 times
# Expected: 'im', Transcribed: 'in' - Occurred 1 times
# Expected: 'drowning', Transcribed: 'the' - Occurred 1 times
# Expected: 'in', Transcribed: 'night' - Occurred 1 times
# Expected: 'night', Transcribed: 'why' - Occurred 1 times
# Expected: 'oh', Transcribed: 'dont' - Occurred 1 times
# Expected: 'when', Transcribed: 'like' - Occurred 1 times
# Expected: 'im', Transcribed: 'this' - Occurred 2 times
# Expected: 'like', Transcribed: 'youre' - Occurred 2 times
# Expected: 'this', Transcribed: 'the' - Occurred 2 times
# Expected: 'youre', Transcribed: 'one' - Occurred 1 times
# Expected: 'one', Transcribed: 'just' - Occurred 1 times
# Expected: 'i', Transcribed: 'hey' - Occurred 1 times
# Expected: 'trust', Transcribed: 'hey' - Occurred 1 times
# Expected: 'hey', Transcribed: 'im' - Occurred 1 times
# Expected: 'hey', Transcribed: 'running' - Occurred 1 times
# Expected: 'im', Transcribed: 'out' - Occurred 1 times
# Expected: 'running', Transcribed: 'of' - Occurred 1 times
# Expected: 'out', Transcribed: 'time' - Occurred 1 times
# Expected: 'of', Transcribed: 'cause' - Occurred 1 times
# Expected: 'cause', Transcribed: 'can' - Occurred 1 times
# Expected: 'see', Transcribed: 'sunlight' - Occurred 1 times
# Expected: 'sun', Transcribed: 'the' - Occurred 1 times
# Expected: 'light', Transcribed: 'sky' - Occurred 1 times
# Expected: 'up', Transcribed: 'so' - Occurred 1 times
# Expected: 'sky', Transcribed: 'hit' - Occurred 1 times
# Expected: 'so', Transcribed: 'the' - Occurred 3 times
# Expected: 'i', Transcribed: 'road' - Occurred 1 times
# Expected: 'hit', Transcribed: 'in' - Occurred 1 times
# Expected: 'the', Transcribed: 'overdrive' - Occurred 1 times
# Expected: 'road', Transcribed: 'baby' - Occurred 1 times
# Expected: 'in', Transcribed: 'oh' - Occurred 2 times
# Expected: 'overdrive', Transcribed: 'the' - Occurred 1 times
# Expected: 'baby', Transcribed: 'citys' - Occurred 1 times
# Expected: 'oh', Transcribed: 'cold' - Occurred 1 times
# Expected: 'citys', Transcribed: 'empty' - Occurred 1 times
# Expected: 'cold', Transcribed: 'no' - Occurred 1 times
# Expected: 'and', Transcribed: 'ones' - Occurred 1 times
# Expected: 'empty', Transcribed: 'around' - Occurred 1 times
# Expected: 'oh', Transcribed: 'to' - Occurred 1 times
# Expected: 'no', Transcribed: 'judge' - Occurred 1 times
# Expected: 'ones', Transcribed: 'me' - Occurred 1 times
# Expected: 'around', Transcribed: 'i' - Occurred 3 times
# Expected: 'to', Transcribed: 'can' - Occurred 2 times
# Expected: 'judge', Transcribed: 'see' - Occurred 1 times
# Expected: 'me', Transcribed: 'clearly' - Occurred 1 times
# Expected: 'cant', Transcribed: 'gone' - Occurred 1 times
# Expected: 'see', Transcribed: 'i' - Occurred 3 times
# Expected: 'clearly', Transcribed: 'said' - Occurred 1 times
# Expected: 'youre', Transcribed: 'im' - Occurred 2 times
# Expected: 'gone', Transcribed: 'blinded' - Occurred 1 times
# Expected: 'i', Transcribed: 'by' - Occurred 1 times
# Expected: 'said', Transcribed: 'the' - Occurred 2 times
# Expected: 'ooh', Transcribed: 'lights' - Occurred 1 times
# Expected: 'blinded', Transcribed: 'i' - Occurred 1 times
# Expected: 'by', Transcribed: 'cant' - Occurred 1 times
# Expected: 'the', Transcribed: 'sleep' - Occurred 2 times
# Expected: 'lights', Transcribed: 'until' - Occurred 1 times
# Expected: 'no', Transcribed: 'i' - Occurred 2 times
# Expected: 'cant', Transcribed: 'your' - Occurred 1 times
# Expected: 'sleep', Transcribed: 'touch' - Occurred 1 times
# Expected: 'until', Transcribed: 'i' - Occurred 1 times
# Expected: 'i', Transcribed: 'said' - Occurred 1 times
# Expected: 'feel', Transcribed: 'ooh' - Occurred 1 times
# Expected: 'your', Transcribed: 'im' - Occurred 2 times
# Expected: 'touch', Transcribed: 'drowning' - Occurred 1 times
# Expected: 'ooh', Transcribed: 'night' - Occurred 1 times
# Expected: 'im', Transcribed: 'oh' - Occurred 2 times
# Expected: 'drowning', Transcribed: 'why' - Occurred 1 times
# Expected: 'in', Transcribed: 'dont' - Occurred 3 times
# Expected: 'the', Transcribed: 'like' - Occurred 4 times
# Expected: 'night', Transcribed: 'this' - Occurred 1 times
# Expected: 'oh', Transcribed: 'youre' - Occurred 1 times
# Expected: 'im', Transcribed: 'one' - Occurred 2 times
# Expected: 'this', Transcribed: 'just' - Occurred 1 times
# Expected: 'the', Transcribed: 'just' - Occurred 2 times
# Expected: 'one', Transcribed: 'coming' - Occurred 1 times
# Expected: 'i', Transcribed: 'back' - Occurred 3 times
# Expected: 'trust', Transcribed: 'to' - Occurred 1 times
# Expected: 'im', Transcribed: 'let' - Occurred 1 times
# Expected: 'just', Transcribed: 'you' - Occurred 4 times
# Expected: 'walking', Transcribed: 'know' - Occurred 1 times
# Expected: 'let', Transcribed: 'never' - Occurred 1 times
# Expected: 'know', Transcribed: 'it' - Occurred 1 times
# Expected: 'by', Transcribed: 'on' - Occurred 1 times
# Expected: 'let', Transcribed: 'phone' - Occurred 1 times
# Expected: 'you', Transcribed: 'well' - Occurred 1 times
# Expected: 'know', Transcribed: 'never' - Occurred 1 times
# Expected: 'i', Transcribed: 'let' - Occurred 2 times
# Expected: 'never', Transcribed: 'go' - Occurred 1 times
# Expected: 'say', Transcribed: 'this' - Occurred 1 times
# Expected: 'it', Transcribed: 'time' - Occurred 1 times
# Expected: 'the', Transcribed: 'said' - Occurred 1 times
# Expected: 'phone', Transcribed: 'ooh' - Occurred 1 times
# Expected: 'say', Transcribed: 'im' - Occurred 2 times
# Expected: 'it', Transcribed: 'blinded' - Occurred 1 times
# Expected: 'on', Transcribed: 'by' - Occurred 1 times
# Expected: 'phone', Transcribed: 'lights' - Occurred 1 times
# Expected: 'will', Transcribed: 'no' - Occurred 1 times
# Expected: 'never', Transcribed: 'i' - Occurred 2 times
# Expected: 'let', Transcribed: 'cant' - Occurred 1 times
# Expected: 'you', Transcribed: 'sleep' - Occurred 1 times
# Expected: 'go', Transcribed: 'until' - Occurred 1 times
# Expected: 'this', Transcribed: 'i' - Occurred 2 times
# Expected: 'time', Transcribed: 'feel' - Occurred 1 times
# Expected: 'ooh', Transcribed: 'your' - Occurred 2 times
# Expected: 'i', Transcribed: 'touch' - Occurred 1 times
# Expected: 'said', Transcribed: 'hey' - Occurred 1 times
# Expected: 'ooh', Transcribed: 'hey' - Occurred 1 times
# Expected: 'blinded', Transcribed: 'hey' - Occurred 1 times
# Expected: 'by', Transcribed: 'hey' - Occurred 1 times
# Expected: 'the', Transcribed: 'hey' - Occurred 1 times
# Expected: 'no', Transcribed: 'said' - Occurred 1 times
# Expected: 'cant', Transcribed: 'im' - Occurred 2 times
# Expected: 'sleep', Transcribed: 'blinded' - Occurred 1 times
# Expected: 'until', Transcribed: 'by' - Occurred 1 times
# Expected: 'feel', Transcribed: 'lights' - Occurred 1 times
# Expected: 'your', Transcribed: 'no' - Occurred 1 times
# Expected: 'touch', Transcribed: 'i' - Occurred 1 times
# Expected: 'hey', Transcribed: 'cant' - Occurred 1 times
# Expected: 'hey', Transcribed: 'sleep' - Occurred 1 times
# Expected: 'hey', Transcribed: 'until' - Occurred 1 times
# Expected: 'said', Transcribed: 'feel' - Occurred 1 times
# Expected: 'im', Transcribed: 'touch' - Occurred 1 times
# Expected: 'blinded', Transcribed: 'thanks' - Occurred 1 times
# Expected: 'by', Transcribed: 'for' - Occurred 1 times
# Expected: 'the', Transcribed: 'watching' - Occurred 1 times
# Expected: 'feeling', Transcribed: 'hair' - Occurred 1 times
# Expected: 'good', Transcribed: 'toss' - Occurred 1 times
# Expected: 'as', Transcribed: 'check' - Occurred 1 times
# Expected: 'hell', Transcribed: 'my' - Occurred 1 times
# Expected: 'hair', Transcribed: 'nails' - Occurred 1 times
# Expected: 'toss', Transcribed: 'baby' - Occurred 1 times
# Expected: 'check', Transcribed: 'how' - Occurred 1 times
# Expected: 'nails', Transcribed: 'feelin' - Occurred 1 times
# Expected: 'baby', Transcribed: 'woo' - Occurred 1 times
# Expected: 'how', Transcribed: 'child' - Occurred 1 times
# Expected: 'you', Transcribed: 'tired' - Occurred 1 times
# Expected: 'feelin', Transcribed: 'of' - Occurred 1 times
# Expected: 'feeling', Transcribed: 'the' - Occurred 1 times
# Expected: 'good', Transcribed: 'bullshit' - Occurred 1 times
# Expected: 'as', Transcribed: 'gone' - Occurred 1 times
# Expected: 'hell', Transcribed: 'dust' - Occurred 1 times
# Expected: 'woo', Transcribed: 'your' - Occurred 1 times
# Expected: 'child', Transcribed: 'shoulders' - Occurred 1 times
# Expected: 'tired', Transcribed: 'off' - Occurred 1 times
# Expected: 'of', Transcribed: 'keep' - Occurred 1 times
# Expected: 'bullshit', Transcribed: 'movin' - Occurred 1 times
# Expected: 'go', Transcribed: 'yes' - Occurred 1 times
# Expected: 'on', Transcribed: 'lord' - Occurred 1 times
# Expected: 'dust', Transcribed: 'tryin' - Occurred 1 times
# Expected: 'your', Transcribed: 'to' - Occurred 3 times
# Expected: 'shoulders', Transcribed: 'get' - Occurred 1 times
# Expected: 'off', Transcribed: 'some' - Occurred 1 times
# Expected: 'keep', Transcribed: 'new' - Occurred 1 times
# Expected: 'it', Transcribed: 'shit' - Occurred 1 times
# Expected: 'moving', Transcribed: 'in' - Occurred 1 times
# Expected: 'yes', Transcribed: 'there' - Occurred 1 times
# Expected: 'lord', Transcribed: 'swimwear' - Occurred 1 times
# Expected: 'tryna', Transcribed: 'goin' - Occurred 1 times
# Expected: 'some', Transcribed: 'the' - Occurred 2 times
# Expected: 'new', Transcribed: 'pool' - Occurred 1 times
# Expected: 'in', Transcribed: 'come' - Occurred 1 times
# Expected: 'there', Transcribed: 'now' - Occurred 1 times
# Expected: 'swimwear', Transcribed: 'come' - Occurred 1 times
# Expected: 'going', Transcribed: 'dry' - Occurred 1 times
# Expected: 'to', Transcribed: 'your' - Occurred 1 times
# Expected: 'the', Transcribed: 'eyes' - Occurred 1 times
# Expected: 'pool', Transcribed: 'you' - Occurred 1 times
# Expected: 'shit', Transcribed: 'know' - Occurred 1 times
# Expected: 'now', Transcribed: 'a' - Occurred 1 times
# Expected: 'come', Transcribed: 'star' - Occurred 1 times
# Expected: 'dry', Transcribed: 'you' - Occurred 1 times
# Expected: 'your', Transcribed: 'can' - Occurred 1 times
# Expected: 'eyes', Transcribed: 'touch' - Occurred 1 times
# Expected: 'know', Transcribed: 'sky' - Occurred 1 times
# Expected: 'a', Transcribed: 'know' - Occurred 1 times
# Expected: 'star', Transcribed: 'that' - Occurred 1 times
# Expected: 'you', Transcribed: 'its' - Occurred 3 times
# Expected: 'can', Transcribed: 'hard' - Occurred 1 times
# Expected: 'touch', Transcribed: 'but' - Occurred 1 times
# Expected: 'sky', Transcribed: 'have' - Occurred 1 times
# Expected: 'i', Transcribed: 'to' - Occurred 2 times
# Expected: 'know', Transcribed: 'try' - Occurred 1 times
# Expected: 'that', Transcribed: 'if' - Occurred 1 times
# Expected: 'hard', Transcribed: 'need' - Occurred 1 times
# Expected: 'but', Transcribed: 'advice' - Occurred 1 times
# Expected: 'you', Transcribed: 'let' - Occurred 3 times
# Expected: 'have', Transcribed: 'me' - Occurred 2 times
# Expected: 'to', Transcribed: 'simplify' - Occurred 1 times
# Expected: 'try', Transcribed: 'if' - Occurred 1 times
# Expected: 'if', Transcribed: 'he' - Occurred 1 times
# Expected: 'need', Transcribed: 'love' - Occurred 1 times
# Expected: 'advice', Transcribed: 'you' - Occurred 1 times
# Expected: 'let', Transcribed: 'anymore' - Occurred 1 times
# Expected: 'me', Transcribed: 'just' - Occurred 1 times
# Expected: 'simplify', Transcribed: 'walk' - Occurred 1 times
# Expected: 'if', Transcribed: 'your' - Occurred 1 times
# Expected: 'he', Transcribed: 'fine' - Occurred 1 times
# Expected: 'dont', Transcribed: 'ass' - Occurred 1 times
# Expected: 'love', Transcribed: 'out' - Occurred 1 times
# ...
# Expected: 'man', Transcribed: 'stupid' - Occurred 1 times
# Expected: 'gotta', Transcribed: 'people' - Occurred 1 times
# Expected: 'pray', Transcribed: 'and' - Occurred 1 times
# Expected: 'to', Transcribed: 'cheap' - Occurred 1 times
# Expected: 'be', Transcribed: 'plans' - Occurred 1 times
# Expected: 'last', Transcribed: 'sure' - Occurred 1 times
# Expected: 'good', Transcribed: 'im' - Occurred 1 times
# Expected: 'night', Transcribed: 'sure' - Occurred 1 times
# Expected: 'and', Transcribed: 'so' - Occurred 1 times
# Expected: 'first', Transcribed: 'gave' - Occurred 1 times
# Expected: 'day', Transcribed: 'million' - Occurred 1 times
# Expected: 'so', Transcribed: 'dollars' - Occurred 1 times
# Expected: 'what', Transcribed: 'just' - Occurred 1 times
# Expected: 'man', Transcribed: 'you' - Occurred 2 times
# Expected: 'do', Transcribed: 'grab' - Occurred 1 times
# Expected: 'what', Transcribed: 'me' - Occurred 1 times
# Expected: 'man', Transcribed: 'the' - Occurred 1 times
# Expected: 'gotta', Transcribed: 'collar' - Occurred 1 times
# Expected: 'totally', Transcribed: 'lock' - Occurred 1 times
# Expected: 'locked', Transcribed: 'on' - Occurred 1 times
# Expected: 'up', Transcribed: 'these' - Occurred 1 times
# Expected: 'by', Transcribed: 'doors' - Occurred 1 times
# Expected: 'what', Transcribed: 'doors' - Occurred 1 times
# Expected: 'man', Transcribed: 'not' - Occurred 1 times
# Expected: 'gotta', Transcribed: 'tryna' - Occurred 1 times
# Expected: 'do', Transcribed: 'be' - Occurred 1 times
# Expected: 'what', Transcribed: 'your' - Occurred 1 times
# Expected: 'a', Transcribed: 'parttime' - Occurred 1 times
# Expected: 'man', Transcribed: 'lover' - Occurred 1 times
# Expected: 'gotta', Transcribed: 'sign' - Occurred 1 times
# Expected: 'prove', Transcribed: 'me' - Occurred 1 times
# Expected: 'be', Transcribed: 'for' - Occurred 1 times
# Expected: 'totally', Transcribed: 'them' - Occurred 1 times
# Expected: 'locked', Transcribed: 'fulltime' - Occurred 1 times
# Expected: 'up', Transcribed: 'im' - Occurred 1 times
# Expected: 'by', Transcribed: 'yours' - Occurred 1 times
# Expected: 'you', Transcribed: 'yours' - Occurred 1 times
# Expected: 'aint', Transcribed: 'so' - Occurred 1 times
# Expected: 'tryna', Transcribed: 'what' - Occurred 1 times
# Expected: 'be', Transcribed: 'a' - Occurred 2 times
# Expected: 'wasting', Transcribed: 'man' - Occurred 1 times
# Expected: 'time', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'stupid', Transcribed: 'what' - Occurred 1 times
# Expected: 'people', Transcribed: 'a' - Occurred 1 times
# Expected: 'in', Transcribed: 'man' - Occurred 1 times
# Expected: 'cheap', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'lines', Transcribed: 'do' - Occurred 1 times
# Expected: 'sure', Transcribed: 'be' - Occurred 1 times
# Expected: 'sure', Transcribed: 'locked' - Occurred 1 times
# Expected: 'id', Transcribed: 'by' - Occurred 1 times
# Expected: 'give', Transcribed: 'you' - Occurred 1 times
# Expected: 'million', Transcribed: 'a' - Occurred 1 times
# Expected: 'dollars', Transcribed: 'man' - Occurred 1 times
# Expected: 'for', Transcribed: 'say' - Occurred 1 times
# Expected: 'you', Transcribed: 'what' - Occurred 1 times
# Expected: 'grab', Transcribed: 'man' - Occurred 1 times
# Expected: 'me', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'by', Transcribed: 'pray' - Occurred 1 times
# Expected: 'collar', Transcribed: 'be' - Occurred 1 times
# Expected: 'knock', Transcribed: 'last' - Occurred 1 times
# Expected: 'on', Transcribed: 'good' - Occurred 1 times
# Expected: 'these', Transcribed: 'night' - Occurred 1 times
# Expected: 'doors', Transcribed: 'and' - Occurred 1 times
# Expected: 'these', Transcribed: 'your' - Occurred 1 times
# Expected: 'doors', Transcribed: 'first' - Occurred 1 times
# Expected: 'not', Transcribed: 'day' - Occurred 1 times
# Expected: 'tryin', Transcribed: 'so' - Occurred 1 times
# Expected: 'to', Transcribed: 'what' - Occurred 1 times
# Expected: 'your', Transcribed: 'man' - Occurred 1 times
# Expected: 'parttime', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'lover', Transcribed: 'do' - Occurred 1 times
# Expected: 'sign', Transcribed: 'what' - Occurred 1 times
# Expected: 'up', Transcribed: 'man' - Occurred 1 times
# Expected: 'for', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'fulltime', Transcribed: 'to' - Occurred 1 times
# Expected: 'yours', Transcribed: 'totally' - Occurred 1 times
# Expected: 'woo', Transcribed: 'by' - Occurred 1 times
# Expected: 'what', Transcribed: 'tell' - Occurred 1 times
# Expected: 'a', Transcribed: 'me' - Occurred 1 times
# Expected: 'man', Transcribed: 'what' - Occurred 6 times
# Expected: 'say', Transcribed: 'man' - Occurred 1 times
# Expected: 'what', Transcribed: 'gotta' - Occurred 6 times
# Expected: 'a', Transcribed: 'do' - Occurred 2 times
# Expected: 'pray', Transcribed: 'man' - Occurred 1 times
# Expected: 'to', Transcribed: 'gotta' - Occurred 2 times
# Expected: 'be', Transcribed: 'do' - Occurred 2 times
# Expected: 'last', Transcribed: 'be' - Occurred 1 times
# Expected: 'good', Transcribed: 'totally' - Occurred 1 times
# Expected: 'night', Transcribed: 'locked' - Occurred 1 times
# Expected: 'your', Transcribed: 'by' - Occurred 1 times
# Expected: 'first', Transcribed: 'you' - Occurred 1 times
# Expected: 'good', Transcribed: 'what' - Occurred 1 times
# Expected: 'day', Transcribed: 'a' - Occurred 1 times
# Expected: 'so', Transcribed: 'man' - Occurred 2 times
# Expected: 'do', Transcribed: 'man' - Occurred 3 times
# Expected: 'a', Transcribed: 'pray' - Occurred 1 times
# Expected: 'man', Transcribed: 'to' - Occurred 2 times
# Expected: 'to', Transcribed: 'last' - Occurred 1 times
# Expected: 'be', Transcribed: 'good' - Occurred 1 times
# Expected: 'totally', Transcribed: 'night' - Occurred 1 times
# Expected: 'locked', Transcribed: 'and' - Occurred 1 times
# Expected: 'up', Transcribed: 'your' - Occurred 1 times
# Expected: 'by', Transcribed: 'first' - Occurred 1 times
# Expected: 'what', Transcribed: 'day' - Occurred 1 times
# Expected: 'prove', Transcribed: 'man' - Occurred 1 times
# Expected: 'totally', Transcribed: 'to' - Occurred 1 times
# Expected: 'locked', Transcribed: 'be' - Occurred 1 times
# Expected: 'up', Transcribed: 'totally' - Occurred 1 times
# Expected: 'by', Transcribed: 'locked' - Occurred 1 times
# Expected: 'oohoohoohoohoohoohoohoohooh', Transcribed: 'by' - Occurred 1 times
# Expected: 'oohoohoohoohoohoohoohoohooh', Transcribed: 'you' - Occurred 1 times
# Expected: 'tell', Transcribed: 'what' - Occurred 1 times
# Expected: 'what', Transcribed: 'man' - Occurred 1 times
# Expected: 'a', Transcribed: 'gotta' - Occurred 1 times
# Expected: 'man', Transcribed: 'do' - Occurred 1 times
# Expected: 'gotta', Transcribed: 'what' - Occurred 1 times
# Expected: 'do', Transcribed: 'a' - Occurred 1 times
# Expected: 'a', Transcribed: 'prove' - Occurred 2 times
# Expected: 'do', Transcribed: 'totally' - Occurred 1 times
# Expected: 'what', Transcribed: 'locked' - Occurred 1 times
# Expected: 'man', Transcribed: 'by' - Occurred 1 times
# Expected: 'nothin', Transcribed: 'nothing' - Occurred 1 times
# Expected: 'made', Transcribed: 'aint' - Occurred 1 times
# Expected: 'mad', Transcribed: 'bad' - Occurred 1 times
# Expected: 'warnin', Transcribed: 'warning' - Occurred 1 times
# Expected: 'breakin', Transcribed: 'breaking' - Occurred 1 times
# Expected: 'fuckin', Transcribed: 'fucking' - Occurred 1 times
# Expected: 'let', Transcribed: 'gonna' - Occurred 1 times
# Expected: 'me', Transcribed: 'start' - Occurred 1 times
# Expected: 'start', Transcribed: 'this' - Occurred 1 times
# Expected: 'this', Transcribed: 'out' - Occurred 1 times
# Expected: 'off', Transcribed: 'by' - Occurred 1 times
# Expected: 'by', Transcribed: 'saying' - Occurred 1 times
# Expected: 'sayin', Transcribed: 'i' - Occurred 1 times
# Expected: 'i', Transcribed: 'really' - Occurred 1 times
# Expected: 'really', Transcribed: 'meant' - Occurred 1 times
# Expected: 'meant', Transcribed: 'well' - Occurred 1 times
# Expected: 'well', Transcribed: 'from' - Occurred 1 times
# Expected: 'the', Transcribed: 'start' - Occurred 1 times
# Expected: 'start', Transcribed: 'take' - Occurred 1 times
# Expected: 'a', Transcribed: 'broken' - Occurred 1 times
# Expected: 'broken', Transcribed: 'man' - Occurred 1 times
# Expected: 'man', Transcribed: 'right' - Occurred 1 times
# Expected: 'my', Transcribed: 'hands' - Occurred 1 times
# Expected: 'hands', Transcribed: 'and' - Occurred 1 times
# Expected: 'and', Transcribed: 'then' - Occurred 1 times
# Expected: 'then', Transcribed: 'put' - Occurred 1 times
# Expected: 'put', Transcribed: 'back' - Occurred 1 times
# Expected: 'back', Transcribed: 'all' - Occurred 1 times
# Expected: 'all', Transcribed: 'his' - Occurred 1 times
# Expected: 'his', Transcribed: 'parts' - Occurred 1 times
# Expected: 'parts', Transcribed: 'but' - Occurred 1 times
# Expected: 'but', Transcribed: 'youre' - Occurred 1 times
# Expected: 'youre', Transcribed: 'not' - Occurred 1 times
# Expected: 'not', Transcribed: 'half' - Occurred 1 times
# Expected: 'half', Transcribed: 'the' - Occurred 1 times
# Expected: 'you', Transcribed: 'think' - Occurred 1 times
# Expected: 'you', Transcribed: 'are' - Occurred 2 times
# Expected: 'cant', Transcribed: 'fill' - Occurred 1 times
# Expected: 'fill', Transcribed: 'the' - Occurred 1 times
# Expected: 'the', Transcribed: 'hole' - Occurred 1 times
# Expected: 'hole', Transcribed: 'inside' - Occurred 1 times
# Expected: 'inside', Transcribed: 'of' - Occurred 1 times
# Expected: 'money', Transcribed: 'girls' - Occurred 1 times
# Expected: 'girls', Transcribed: 'and' - Occurred 1 times
# Expected: 'and', Transcribed: 'cars' - Occurred 1 times
# Expected: 'cars', Transcribed: 'im' - Occurred 1 times
# Expected: 'im', Transcribed: 'so' - Occurred 1 times
# Expected: 'so', Transcribed: 'glad' - Occurred 1 times
# Expected: 'glad', Transcribed: 'i' - Occurred 1 times
# Expected: 'never', Transcribed: 'ever' - Occurred 1 times
# Expected: 'ever', Transcribed: 'had' - Occurred 1 times
# Expected: 'had', Transcribed: 'a' - Occurred 1 times
# Expected: 'a', Transcribed: 'baby' - Occurred 1 times
# Expected: 'baby', Transcribed: 'with' - Occurred 1 times
# Expected: 'you', Transcribed: 'cause' - Occurred 1 times
# Expected: 'cant', Transcribed: 'love' - Occurred 1 times
# Expected: 'love', Transcribed: 'nothing' - Occurred 1 times
# Expected: 'nothin', Transcribed: 'unless' - Occurred 1 times
# Expected: 'unless', Transcribed: 'theres' - Occurred 1 times
# Expected: 'theres', Transcribed: 'something' - Occurred 1 times
# Expected: 'somethin', Transcribed: 'in' - Occurred 1 times
# Expected: 'feel', Transcribed: 'so' - Occurred 2 times
# Expected: 'so', Transcribed: 'sorry' - Occurred 1 times
# Expected: 'sorry', Transcribed: 'i' - Occurred 2 times
# Expected: 'so', Transcribed: 'sad' - Occurred 1 times
# Expected: 'i', Transcribed: 'tried' - Occurred 1 times
# Expected: 'feel', Transcribed: 'to' - Occurred 1 times
# Expected: 'so', Transcribed: 'help' - Occurred 1 times
# Expected: 'sad', Transcribed: 'you' - Occurred 1 times
# Expected: 'feel', Transcribed: 'just' - Occurred 1 times
# Expected: 'so', Transcribed: 'aint' - Occurred 1 times
# Expected: 'sad', Transcribed: 'too' - Occurred 1 times
# Expected: 'tried', Transcribed: 'and' - Occurred 1 times
# Expected: 'help', Transcribed: 'had' - Occurred 1 times
# Expected: 'i', Transcribed: 'warning' - Occurred 1 times
# Expected: 'tried', Transcribed: 'about' - Occurred 1 times
# Expected: 'to', Transcribed: 'who' - Occurred 1 times
# Expected: 'help', Transcribed: 'you' - Occurred 1 times
# Expected: 'just', Transcribed: 'glad' - Occurred 1 times
# Expected: 'you', Transcribed: 'made' - Occurred 1 times
# Expected: 'mad', Transcribed: 'it' - Occurred 1 times
# Expected: 'and', Transcribed: 'out' - Occurred 1 times
# Expected: 'i', Transcribed: 'without' - Occurred 1 times
# Expected: 'had', Transcribed: 'breaking' - Occurred 1 times
# Expected: 'no', Transcribed: 'down' - Occurred 1 times
# Expected: 'warnin', Transcribed: 'oh' - Occurred 1 times
# Expected: 'had', Transcribed: 'feel' - Occurred 1 times
# Expected: 'no', Transcribed: 'so' - Occurred 1 times
# Expected: 'warnin', Transcribed: 'sorry' - Occurred 1 times
# Expected: 'about', Transcribed: 'i' - Occurred 1 times
# Expected: 'who', Transcribed: 'feel' - Occurred 1 times
# Expected: 'are', Transcribed: 'sad' - Occurred 1 times
# Expected: 'bout', Transcribed: 'i' - Occurred 1 times
# Expected: 'who', Transcribed: 'tried' - Occurred 1 times
# Expected: 'just', Transcribed: 'help' - Occurred 1 times
# Expected: 'glad', Transcribed: 'you' - Occurred 1 times
# Expected: 'made', Transcribed: 'just' - Occurred 1 times
# Expected: 'it', Transcribed: 'aint' - Occurred 1 times
# Expected: 'out', Transcribed: 'too' - Occurred 1 times
# Expected: 'without', Transcribed: 'bad' - Occurred 1 times
# Expected: 'breakin', Transcribed: 'and' - Occurred 1 times
# Expected: 'oh', Transcribed: 'had' - Occurred 1 times
# Expected: 'feel', Transcribed: 'warning' - Occurred 1 times
# Expected: 'so', Transcribed: 'about' - Occurred 2 times
# Expected: 'sorry', Transcribed: 'who' - Occurred 2 times
# Expected: 'feel', Transcribed: 'are' - Occurred 2 times
# Expected: 'so', Transcribed: 'ay' - Occurred 2 times
# Expected: 'sad', Transcribed: 'ay' - Occurred 2 times
# Expected: 'i', Transcribed: 'ay' - Occurred 2 times
# Expected: 'feel', Transcribed: 'ay' - Occurred 1 times
# Expected: 'tried', Transcribed: 'ay' - Occurred 1 times
# Expected: 'to', Transcribed: 'ay' - Occurred 1 times
# Expected: 'help', Transcribed: 'ay' - Occurred 1 times
# Expected: 'you', Transcribed: 'ay' - Occurred 1 times
# Expected: 'tried', Transcribed: 'youre' - Occurred 1 times
# Expected: 'to', Transcribed: 'not' - Occurred 1 times
# Expected: 'help', Transcribed: 'half' - Occurred 1 times
# Expected: 'it', Transcribed: 'man' - Occurred 1 times
# Expected: 'made', Transcribed: 'think' - Occurred 1 times
# Expected: 'mad', Transcribed: 'you' - Occurred 1 times
# Expected: 'and', Transcribed: 'are' - Occurred 1 times
# Expected: 'warnin', Transcribed: 'fill' - Occurred 1 times
# Expected: 'had', Transcribed: 'hole' - Occurred 1 times
# Expected: 'no', Transcribed: 'inside' - Occurred 1 times
# Expected: 'about', Transcribed: 'of' - Occurred 1 times
# Expected: 'who', Transcribed: 'you' - Occurred 1 times
# Expected: 'are', Transcribed: 'money' - Occurred 1 times
# Expected: 'bout', Transcribed: 'drugs' - Occurred 1 times
# Expected: 'who', Transcribed: 'and' - Occurred 1 times
# Expected: 'you', Transcribed: 'cars' - Occurred 1 times
# Expected: 'who', Transcribed: 'so' - Occurred 1 times
# Expected: 'you', Transcribed: 'glad' - Occurred 1 times
# Expected: 'are', Transcribed: 'i' - Occurred 1 times
# Expected: 'hey', Transcribed: 'never' - Occurred 1 times
# Expected: 'hey', Transcribed: 'ever' - Occurred 1 times
# Expected: 'hey', Transcribed: 'had' - Occurred 1 times
# Expected: 'hey', Transcribed: 'a' - Occurred 1 times
# Expected: 'cause', Transcribed: 'baby' - Occurred 1 times
# Expected: 'youre', Transcribed: 'with' - Occurred 1 times
# Expected: 'not', Transcribed: 'you' - Occurred 1 times
# Expected: 'half', Transcribed: 'cause' - Occurred 1 times
# Expected: 'man', Transcribed: 'cant' - Occurred 1 times
# Expected: 'think', Transcribed: 'nothing' - Occurred 1 times
# Expected: 'that', Transcribed: 'unless' - Occurred 1 times
# Expected: 'you', Transcribed: 'theres' - Occurred 1 times
# Expected: 'are', Transcribed: 'something' - Occurred 1 times
# Expected: 'cant', Transcribed: 'for' - Occurred 1 times
# Expected: 'fill', Transcribed: 'you' - Occurred 1 times
# Expected: 'hole', Transcribed: 'feel' - Occurred 1 times
# Expected: 'inside', Transcribed: 'so' - Occurred 1 times
# Expected: 'of', Transcribed: 'sad' - Occurred 1 times
# Expected: 'with', Transcribed: 'should' - Occurred 2 times
# Expected: 'money', Transcribed: 'be' - Occurred 1 times
# Expected: 'drugs', Transcribed: 'sad' - Occurred 1 times
# Expected: 'cars', Transcribed: 'should' - Occurred 1 times
# Expected: 'glad', Transcribed: 'should' - Occurred 1 times
# Expected: 'never', Transcribed: 'sad' - Occurred 1 times
# Expected: 'had', Transcribed: 'should' - Occurred 1 times
# Expected: 'cant', Transcribed: 'be' - Occurred 1 times
# Expected: 'nothin', Transcribed: 'should' - Occurred 1 times
# Expected: 'unless', Transcribed: 'be' - Occurred 1 times

# %%
import matplotlib.pyplot as plt
import numpy as np
top_mismatches = mismatch_counter.most_common(20)

words = [f"{truth} -> {hypo}" for truth, hypo in [item[0] for item in top_mismatches]]
counts = [item[1] for item in top_mismatches]
sizes = [count * 10 for count in counts]

fig, ax = plt.subplots(figsize=(14, 8))
bubble = ax.scatter(words, np.zeros_like(words), s=sizes, alpha=0.5, color=np.random.rand(len(words), 3))

ax.set_title('Top 20 Mismatched Words in Transcriptions', fontsize=16)
ax.set_xlabel('Mismatched Words', fontsize=12)
plt.xticks(rotation=45, ha='right')

ax.yaxis.set_visible(False)

for i, txt in enumerate(counts):
    ax.annotate(txt, (words[i], 0), textcoords="offset points", xytext=(0,10), ha='center')

plt.show()
